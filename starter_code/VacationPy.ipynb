# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0     margaret river -33.9500  115.0667    284.97        87
# 1        1  wailua homesteads  22.0669 -159.3780    301.39        70
# 2        2       saint-pierre -21.3393   55.4781    294.02        73
# 3        3       punta arenas -53.1500  -70.9167    282.21        57
# 4        4  port-aux-francais -49.3500   70.2167    274.72        73
#
#    Cloudiness  Wind Speed Country        Date
# 0           4        2.38      AU  1695935337
# 1          20        5.66      US  1695935337
# 2          20        3.09      RE  1695935338
# 3           0        6.17      CL  1695935338
# 4          27       15.33      TF  1695935338

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Create a map with points for each city, where the size of the point represents humidity
humidity_map = city_data_df.hvplot.points(
    x='Lng',
    y='Lat',
    c='Humidity',  
    geo=True,
    tiles="OSM",  
    width=800,
    height=600,
    colorbar=True,  
    size='Humidity',  
    title='City Humidity',
    xlabel="Longitude",
    ylabel="Latitude"
)

# Display the interactive map
humidity_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Define criteria
max_temp_lower = 20
max_temp_upper = 30
max_wind_speed = 5
max_cloudiness = 0

# Convert temperature from Kelvin to Celsius
city_data_df['Max Temp (C)'] = city_data_df['Max Temp'] - 273.15

# Filter the DataFrame based on the criteria
ideal_cities_df = city_data_df[
    (city_data_df['Max Temp (C)'] > max_temp_lower) &
    (city_data_df['Max Temp (C)'] < max_temp_upper) &
    (city_data_df['Wind Speed'] < max_wind_speed) &
    (city_data_df['Cloudiness'] == max_cloudiness)
].copy()

# Drop any rows with null values
ideal_cities_df.dropna(inplace=True)

# Display sample data of ideal cities
ideal_cities_df.head()
# Out:
#     City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 11       11        page  36.9147 -111.4558    302.03        16           0
# 13       13      zaltan  32.9470   11.8665    297.89        69           0
# 45       45    holualoa  19.6228 -155.9522    301.23        68           0
# 68       68       sirte  31.2089   16.5887    297.67        67           0
# 84       84  maintirano -18.0667   44.0167    298.69        73           0
#
#     Wind Speed Country        Date  Max Temp (C)
# 11        2.68      US  1695935047         28.88
# 13        3.03      LY  1695935339         24.74
# 45        4.12      US  1695935320         28.08
# 68        3.86      LY  1695935348         24.52
# 84        1.45      MG  1695935350         25.54

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Create a new DataFrame hotel_df to store city, country, coordinates, and humidity
hotel_df = ideal_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column "Hotel Name" to the DataFrame
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                              City Country      Lat       Lng  Humidity  \
# 11                           page      US  36.9147 -111.4558        16
# 13                         zaltan      LY  32.9470   11.8665        69
# 45                       holualoa      US  19.6228 -155.9522        68
# 68                          sirte      LY  31.2089   16.5887        67
# 84                     maintirano      MG -18.0667   44.0167        73
# 113                   las lomitas      AR -24.7096  -60.5930        21
# 148                      hannibal      US  39.7084  -91.3585        47
# 200  chak thirty-one -eleven left      PK  30.4333   72.7000        36
# 214                   al burayqah      LY  30.4062   19.5739        67
# 226               figuig (centre)      MA  32.1089   -1.2286        25
# 235                       fomboni      KM -12.2800   43.7425        80
# 243                    morristown      US  36.2140  -83.2949        59
# 247                        naples      IT  40.8333   14.2500        76
# 251                         ubari      LY  26.5921   12.7805        28
# 261                         uthal      PK  25.8072   66.6219        68
# 263                hassi messaoud      DZ  31.6804    6.0729        38
# 294                        sirvan      AZ  39.9379   48.9286        62
# 299                hafar al-batin      SA  28.4328   45.9708        14
# 328                    birzebbuga      MT  35.8258   14.5269        83
# 365                    balkanabat      TM  39.5108   54.3671        35
# 374                         datca      TR  36.7378   27.6842        74
# 377                      oromocto      CA  45.8351  -66.4792        46
# 387                     ambovombe      MG -25.1667   46.0833        64
# 421                        ormara      PK  25.2088   64.6357        76
# 441                     armstrong      AR -32.7822  -61.6022        22
# 453                        maceio      BR  -9.6658  -35.7353        78
# 468         isola di capo rizzuto      IT  38.9600   17.0933        63
# 481                          chak      PK  27.8575   68.8329        78
# 484                        tumayr      SA  25.7039   45.8680        15
# 485                    shenjiamen      CN  29.9576  122.2980        82
# 513                    hanceville      US  34.0607  -86.7675        39
# 518                          bafq      IR  31.6128   55.4107        29
#
#     Hotel Name
# 11
# 13
# 45
# 68
# 84
# 113
# 148
# 200
# 214
# 226
# 235
# 243
# 247
# 251
# 261
# 263
# 294
# 299
# 328
# 365
# 374
# 377
# 387
# 421
# 441
# 453
# 468
# 481
# 484
# 485
# 513
# 518

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set the parameters for the type of place
categories = "accommodation.hotel"
radius = 10000

params = {
    "categories":categories,
    "apiKey":geoapify_key    
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    data = response.json()

    # Check if any hotels were found and if the first result has a "name" property
    if "features" in data and len(data["features"]) > 0 and "name" in data["features"][0]["properties"]:
        # Get the name of the first hotel in the results
        hotel_name = data["features"][0]["properties"]["name"]
        hotel_df.loc[index, "Hotel Name"] = hotel_name
    else:
        # If no hotel is found or the "name" property is missing, set the hotel name as "No hotel found"
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# page - nearest hotel: Clarion Inn Page - Lake Powell
# zaltan - nearest hotel: No hotel found
# holualoa - nearest hotel: Kona Hotel
# sirte - nearest hotel: فندق المدينة-سرت
# maintirano - nearest hotel: Hotel Safari
# las lomitas - nearest hotel: Hotel Lomitas
# hannibal - nearest hotel: Best Western On The River
# chak thirty-one -eleven left - nearest hotel: No hotel found
# al burayqah - nearest hotel: فندق ماس ليبيا
# figuig (centre) - nearest hotel: No hotel found
# fomboni - nearest hotel: Mohéli La Plage
# morristown - nearest hotel: Days Inn
# naples - nearest hotel: Hotel Miramare
# ubari - nearest hotel: فندق اوباري
# uthal - nearest hotel: No hotel found
# hassi messaoud - nearest hotel: AMC
# sirvan - nearest hotel: No hotel found
# hafar al-batin - nearest hotel: فندق الفرحان
# birzebbuga - nearest hotel: Seabreeze
# balkanabat - nearest hotel: Nebitçi
# datca - nearest hotel: Marphe Hotel
# oromocto - nearest hotel: Days Inn
# ambovombe - nearest hotel: La source
# ormara - nearest hotel: No hotel found
# armstrong - nearest hotel: San Carlos
# maceio - nearest hotel: Maceió Hostel e Pousada
# isola di capo rizzuto - nearest hotel: No hotel found
# chak - nearest hotel: No hotel found
# tumayr - nearest hotel: No hotel found
# shenjiamen - nearest hotel: Zhonghan Hotel
# hanceville - nearest hotel: No hotel found
# bafq - nearest hotel: هتل رستوران علمدار
#                              City Country      Lat       Lng  Humidity  \
# 11                           page      US  36.9147 -111.4558        16
# 13                         zaltan      LY  32.9470   11.8665        69
# 45                       holualoa      US  19.6228 -155.9522        68
# 68                          sirte      LY  31.2089   16.5887        67
# 84                     maintirano      MG -18.0667   44.0167        73
# 113                   las lomitas      AR -24.7096  -60.5930        21
# 148                      hannibal      US  39.7084  -91.3585        47
# 200  chak thirty-one -eleven left      PK  30.4333   72.7000        36
# 214                   al burayqah      LY  30.4062   19.5739        67
# 226               figuig (centre)      MA  32.1089   -1.2286        25
# 235                       fomboni      KM -12.2800   43.7425        80
# 243                    morristown      US  36.2140  -83.2949        59
# 247                        naples      IT  40.8333   14.2500        76
# 251                         ubari      LY  26.5921   12.7805        28
# 261                         uthal      PK  25.8072   66.6219        68
# 263                hassi messaoud      DZ  31.6804    6.0729        38
# 294                        sirvan      AZ  39.9379   48.9286        62
# 299                hafar al-batin      SA  28.4328   45.9708        14
# 328                    birzebbuga      MT  35.8258   14.5269        83
# 365                    balkanabat      TM  39.5108   54.3671        35
# 374                         datca      TR  36.7378   27.6842        74
# 377                      oromocto      CA  45.8351  -66.4792        46
# 387                     ambovombe      MG -25.1667   46.0833        64
# 421                        ormara      PK  25.2088   64.6357        76
# 441                     armstrong      AR -32.7822  -61.6022        22
# 453                        maceio      BR  -9.6658  -35.7353        78
# 468         isola di capo rizzuto      IT  38.9600   17.0933        63
# 481                          chak      PK  27.8575   68.8329        78
# 484                        tumayr      SA  25.7039   45.8680        15
# 485                    shenjiamen      CN  29.9576  122.2980        82
# 513                    hanceville      US  34.0607  -86.7675        39
# 518                          bafq      IR  31.6128   55.4107        29
#
#                          Hotel Name
# 11   Clarion Inn Page - Lake Powell
# 13                   No hotel found
# 45                       Kona Hotel
# 68                 فندق المدينة-سرت
# 84                     Hotel Safari
# 113                   Hotel Lomitas
# 148       Best Western On The River
# 200                  No hotel found
# 214                  فندق ماس ليبيا
# 226                  No hotel found
# 235                 Mohéli La Plage
# 243                        Days Inn
# 247                  Hotel Miramare
# 251                     فندق اوباري
# 261                  No hotel found
# 263                             AMC
# 294                  No hotel found
# 299                    فندق الفرحان
# 328                       Seabreeze
# 365                         Nebitçi
# 374                    Marphe Hotel
# 377                        Days Inn
# 387                       La source
# 421                  No hotel found
# 441                      San Carlos
# 453         Maceió Hostel e Pousada
# 468                  No hotel found
# 481                  No hotel found
# 484                  No hotel found
# 485                  Zhonghan Hotel
# 513                  No hotel found
# 518              هتل رستوران علمدار

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map
hotel_map_plot = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo=True,
    tiles="OSM",
    frame_width=800,
    frame_height=600,
    c="Humidity",  
    cmap="magma",  
    colorbar=True,  
    size=20,  
    hover_cols=["City", "Country", "Hotel Name"],
    xlabel="Lon",  
    ylabel="Lat",  
)

# Display the map plot
hotel_map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity,City,Country,Hotel Name)
